# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x5 = np.linspace(0,10,1000)
plt.figure()
ax = plt.axes()
ax.plot(x5,np.sin(x5),'b-')

# %%
ypoint = np.array([3,5,8,9])
xpoint = np.array([1,3,5,7])
plt.plot(xpoint,ypoint,linestyle = 'dashed',color="purple",linewidth=5)
plt.xlabel("Hello")
plt.xlabel("Hello")
# Out:
# Text(0.5, 0, 'Hello')
