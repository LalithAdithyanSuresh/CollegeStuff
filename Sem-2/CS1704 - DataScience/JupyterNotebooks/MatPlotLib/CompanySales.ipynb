# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

Sales = pd.read_csv('/content/company_sales_data.csv')

# %% [markdown]
# ### **TOTAL PROFIT GRAPH**

# %%
plt.plot(Sales['total_profit'],'X-.g')

# %%
plt.plot(Sales['total_profit'],'o:r',linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sold units Number')
plt.title('Monthly Prices Line Graph')
plt.legend(['Total Prices'],title="Legend",frameon=True,loc=2)

# %%
itemSales = Sales.iloc[:,1:7]
plt.plot(itemSales)

# %%
plt.scatter(Sales['month_number'],Sales['toothpaste'])

# %%
plt.bar(Sales['month_number'],Sales['facecream'])
plt.bar(Sales['month_number'],Sales['facewash'])
plt.legend(['facecream','facewash'])

# %%
plt.bar(Sales['month_number'],Sales['bathingsoap'])
# Out:
# <BarContainer object of 12 artists>

# %%
plt.hist(Sales['total_profit'])
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <BarContainer object of 10 artists>)

# %%
print(Sales)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
labels = [x for x in itemSales]
Totals = [Sales[x].sum() for x in itemSales]
plt.pie(Totals,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7bf713c7b580>,
# ...
#  [Text(1.0191857113582774, 0.4138363030995739, 'facecream'),
#   Text(0.6140655913722997, 0.912646398936953, 'facewash'),
#   Text(-0.4252111998343268, 1.0144926986112084, 'toothpaste'),
#   Text(-0.6978920809686103, -0.8502626907734472, 'bathingsoap'),
#   Text(0.8424027164269657, -0.7073596421598204, 'shampoo'),
#   Text(1.0764907254787095, -0.226202824823922, 'moisturizer')])
