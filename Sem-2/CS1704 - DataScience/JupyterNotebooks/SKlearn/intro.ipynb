# %% [markdown]
# ### Tutorial on how to use SK learn

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creating General Dataframes
DF = np.random.randint(0,500,30)
DF = pd.DataFrame(DF)
Xaxis = np.arange(30)

# %%
mm = MinMaxScaler()

# %%
Transformed = mm.fit_transform(DF)
# Transformed = mm.fit(DF)

# %%
plt.scatter(Xaxis,Transformed)
plt.show()
