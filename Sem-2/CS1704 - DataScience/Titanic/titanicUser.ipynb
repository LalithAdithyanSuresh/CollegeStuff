# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
File = pd.read_csv('titanic.csv')

# %%
# Storing Age column to see difference
Age = pd.Series(File['Age'])

# Print File
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Functions

# %% [markdown]
#     -> One-hot Encoder

# %%
File['Sex'] = File['Sex'].astype('category')
a = pd.get_dummies(File['Sex']).astype(int)
File = File.join(a)
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#     -> Label Encoder

# %%
encoder = LabelEncoder()
File['Embarked'] = encoder.fit_transform(File['Embarked'])
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#     -> Dropping Columns

# %%
# File = File.drop(['PassengerId','Sex'],axis=1)
File = File.drop([0,1,6,7,8])
File
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# ...

# %% [markdown]
#     -> Z-score Scaler

# %%
Mean = File['Age'].mean()
StDev = File['Age'].std()

zScore = pd.Series((File['Age'] - Mean)/StDev , name='Z-Score ( Age )')
File = File.join(zScore)
plt.hist(zScore)
plt.title('Z-Score of Age')
File
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# ...

# %% [markdown]
#     -> Min-Max Scaler

# %%
Min = File['Age'].min()
Max = File['Age'].max()

MMScaler = pd.Series((File['Age'] - Min)/(Max-Min),name = 'Min-Max Scaler ( age )')
File = File.join(MMScaler)
plt.hist(MMScaler)
plt.title('Min - Max Scaler of Age')
File
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# ...

# %% [markdown]
#     -> IQR

# %%
Q1 = File['Age'].quantile(0.25)
Q3 = File['Age'].quantile(0.75)
IQR = Q3-Q1

# %%
# Lower Fence
LowerFence = Q1 - 1.5 * IQR
# Upper Fence
UpperFence = Q3 + 1.5 * IQR

# %% [markdown]
#     -> Removing Outliers

# %%
File = File.query("Age > @LowerFence and Age < @UpperFence")
plt.subplot(1,2,1)
plt.hist(File['Age'])
plt.title('Age (Before)')
plt.subplot(1,2,2)
plt.hist(Age)
plt.title('Age (after)')
# Out:
# Text(0.5, 1.0, 'Age (after)')

# %% [markdown]
# #### Model Training

# %%
#Import Modules
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
#     -> Getting Dataframe Ready

# %%
NewDataFrame = pd.DataFrame(File)
NewDataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 10                Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# ...

# %%
NewDataFrame = pd.DataFrame(File)
NewDataFrame = NewDataFrame.drop(['PassengerId','Z-Score ( Age )','Name','Min-Max Scaler ( age )','Sex','Ticket','Cabin'],axis = 1)
NewDataFrame
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  female  male
# 2           1       3  26.0      0      0   7.9250         2       1     0
# 3           1       1  35.0      1      0  53.1000         2       1     0
# 4           0       3  35.0      0      0   8.0500         2       0     1
# 9           1       2  14.0      1      0  30.0708         0       1     0
# 10          1       3   4.0      1      1  16.7000         2       1     0
# ..        ...     ...   ...    ...    ...      ...       ...     ...   ...
# 885         0       3  39.0      0      5  29.1250         1       1     0
# 886         0       2  27.0      0      0  13.0000         2       0     1
# 887         1       1  19.0      0      0  30.0000         2       1     0
# 889         1       1  26.0      0      0  30.0000         0       0     1
# 890         0       3  32.0      0      0   7.7500         1       0     1
#
# [698 rows x 9 columns]

# %% [markdown]
#     -> Dataset Split

# %%
X = NewDataFrame.loc[:,NewDataFrame.columns != 'Survived']
y = NewDataFrame['Survived']

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
# Print Splitted Data
print(x_train,x_test,y_train,y_test)
# Out:
#      Pclass    Age  SibSp  Parch     Fare  Embarked  female  male
# 430       1  28.00      0      0   26.550         2       0     1
# 83        1  28.00      0      0   47.100         2       0     1
# 467       1  56.00      0      0   26.550         2       0     1
# 288       2  42.00      0      0   13.000         2       0     1
# 806       1  39.00      0      0    0.000         2       0     1
# ..      ...    ...    ...    ...      ...       ...     ...   ...
# 520       1  30.00      0      0   93.500         2       1     0
# 508       3  28.00      0      0   22.525         2       0     1
# 305       1   0.92      1      2  151.550         2       0     1
# 232       2  59.00      0      0   13.500         2       0     1
# 142       3  24.00      1      0   15.850         2       1     0
#
# [523 rows x 8 columns]      Pclass   Age  SibSp  Parch      Fare  Embarked  female  male
# 233       3   5.0      4      2   31.3875         2       1     0
# ...

# %% [markdown]
#     -> Logistic Regression

# %%
regressionFunc = LogisticRegression()
regressionFunc.fit(x_train,y_train)
# Out:
# C:\Users\lalit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
#     -> Accuracy Of the Model

# %%
# Accuracy Prediction
y_pred = regressionFunc.predict(x_test)
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 77.14285714285715

# %% [markdown]
#     -> Regression model Line

# %%
print("Co efficient : ",regressionFunc.coef_)
print("Intercept : ",regressionFunc.intercept_)
# Out:
# Co efficient :  [[-1.18034626 -0.04289746 -0.46099175 -0.13493809  0.00194753 -0.09448907
#    1.84124438 -0.81644273]]
# Intercept :  [3.69698875]
