# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
File = pd.read_csv('titanic.csv')

# %%
# Storing Age column to see difference
Age = pd.Series(File['Age'])

# Print File
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Functions

# %% [markdown]
#     -> One-hot Encoder

# %%
File['Sex'] = File['Sex'].astype('category')
a = pd.get_dummies(File['Sex']).astype(int)
File = File.join(a)
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  female  male
# 0        0         A/5 21171   7.2500   NaN        S       0     1
# 1        0          PC 17599  71.2833   C85        C       1     0
# 2        0  STON/O2. 3101282   7.9250   NaN        S       1     0
# 3        0            113803  53.1000  C123        S       1     0
# 4        0            373450   8.0500   NaN        S       0     1
# ..     ...               ...      ...   ...      ...     ...   ...
# 886      0            211536  13.0000   NaN        S       0     1
# 887      0            112053  30.0000   B42        S       1     0
# 888      2        W./C. 6607  23.4500   NaN        S       1     0
# 889      0            111369  30.0000  C148        C       0     1
# 890      0            370376   7.7500   NaN        Q       0     1
#
# [891 rows x 14 columns]

# %% [markdown]
#     -> Label Encoder

# %%
encoder = LabelEncoder()
File['Embarked'] = encoder.fit_transform(File['Embarked'])
File
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin  Embarked  female  male
# 0        0         A/5 21171   7.2500   NaN         2       0     1
# 1        0          PC 17599  71.2833   C85         0       1     0
# 2        0  STON/O2. 3101282   7.9250   NaN         2       1     0
# 3        0            113803  53.1000  C123         2       1     0
# 4        0            373450   8.0500   NaN         2       0     1
# ..     ...               ...      ...   ...       ...     ...   ...
# 886      0            211536  13.0000   NaN         2       0     1
# 887      0            112053  30.0000   B42         2       1     0
# 888      2        W./C. 6607  23.4500   NaN         2       1     0
# 889      0            111369  30.0000  C148         0       0     1
# 890      0            370376   7.7500   NaN         1       0     1
#
# [891 rows x 14 columns]

# %% [markdown]
#     -> Dropping Columns

# %%
File = File.drop(['PassengerId','Sex'],axis=1)
File
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare Cabin  Embarked  female  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN         2       0
# 1    38.0      1      0          PC 17599  71.2833   C85         0       1
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN         2       1
# 3    35.0      1      0            113803  53.1000  C123         2       1
# 4    35.0      0      0            373450   8.0500   NaN         2       0
# ..    ...    ...    ...               ...      ...   ...       ...     ...
# 886  27.0      0      0            211536  13.0000   NaN         2       0
# 887  19.0      0      0            112053  30.0000   B42         2       1
# 888   NaN      1      2        W./C. 6607  23.4500   NaN         2       1
# 889  26.0      0      0            111369  30.0000  C148         0       0
# 890  32.0      0      0            370376   7.7500   NaN         1       0
#
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 12 columns]

# %% [markdown]
#     -> Z-score Scaler

# %%
Mean = File['Age'].mean()
StDev = File['Age'].std()

zScore = pd.Series((File['Age'] - Mean)/StDev , name='Z-Score ( Age )')
File = File.join(zScore)
plt.hist(zScore)
plt.title('Z-Score of Age')
File
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare Cabin  Embarked  female  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN         2       0
# 1    38.0      1      0          PC 17599  71.2833   C85         0       1
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN         2       1
# 3    35.0      1      0            113803  53.1000  C123         2       1
# 4    35.0      0      0            373450   8.0500   NaN         2       0
# ..    ...    ...    ...               ...      ...   ...       ...     ...
# 886  27.0      0      0            211536  13.0000   NaN         2       0
# 887  19.0      0      0            112053  30.0000   B42         2       1
# 888   NaN      1      2        W./C. 6607  23.4500   NaN         2       1
# 889  26.0      0      0            111369  30.0000  C148         0       0
# 890  32.0      0      0            370376   7.7500   NaN         1       0
#
#      male  Z-Score ( Age )
# 0       1        -0.530005
# 1       0         0.571430
# 2       0        -0.254646
# 3       0         0.364911
# 4       1         0.364911
# ..    ...              ...
# 886     1        -0.185807
# 887     0        -0.736524
# 888     0              NaN
# 889     1        -0.254646
# 890     1         0.158392
#
# [891 rows x 13 columns]

# %% [markdown]
#     -> Min-Max Scaler

# %%
Min = File['Age'].min()
Max = File['Age'].max()

MMScaler = pd.Series((File['Age'] - Min)/(Max-Min),name = 'Min-Max Scaler ( age )')
File = File.join(MMScaler)
plt.hist(MMScaler)
plt.title('Min - Max Scaler of Age')
File
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare Cabin  Embarked  female  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN         2       0
# 1    38.0      1      0          PC 17599  71.2833   C85         0       1
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN         2       1
# 3    35.0      1      0            113803  53.1000  C123         2       1
# 4    35.0      0      0            373450   8.0500   NaN         2       0
# ..    ...    ...    ...               ...      ...   ...       ...     ...
# 886  27.0      0      0            211536  13.0000   NaN         2       0
# 887  19.0      0      0            112053  30.0000   B42         2       1
# 888   NaN      1      2        W./C. 6607  23.4500   NaN         2       1
# 889  26.0      0      0            111369  30.0000  C148         0       0
# 890  32.0      0      0            370376   7.7500   NaN         1       0
#
#      male  Z-Score ( Age )  Min-Max Scaler ( age )
# 0       1        -0.530005                0.271174
# 1       0         0.571430                0.472229
# 2       0        -0.254646                0.321438
# 3       0         0.364911                0.434531
# 4       1         0.364911                0.434531
# ..    ...              ...                     ...
# 886     1        -0.185807                0.334004
# 887     0        -0.736524                0.233476
# 888     0              NaN                     NaN
# 889     1        -0.254646                0.321438
# 890     1         0.158392                0.396833
#
# [891 rows x 14 columns]

# %% [markdown]
#     -> IQR

# %%
Q1 = File['Age'].quantile(0.25)
Q3 = File['Age'].quantile(0.75)
IQR = Q3-Q1

# %%
# Lower Fence
LowerFence = Q1 - 1.5 * IQR
# Upper Fence
UpperFence = Q3 + 1.5 * IQR

# %% [markdown]
#     -> Removing Outliers

# %%
File = File.query("Age > @LowerFence and Age < @UpperFence")
plt.subplot(1,2,1)
plt.hist(File['Age'])
plt.title('Age (Before)')
plt.subplot(1,2,2)
plt.hist(Age)
plt.title('Age (after)')
# Out:
# Text(0.5, 1.0, 'Age (after)')
